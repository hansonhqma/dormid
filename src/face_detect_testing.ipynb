# %%
import numpy as np
import cv2 as cv
import cvlib as cb
import os
import matplotlib.pyplot as plt
import model

# %%
a = cv.imread('pic.JPG')
plt.imshow(a)

# %%
b = cv.imread('notme.jpg')
plt.imshow(b)

# %%
e = model.engine(model.INPUT_SHAPE)
e.model.load_weights('GEN9.hdf5')

# %%
e.predict(a, b)
# Out:
# array([[0.31767356]], dtype=float32)
